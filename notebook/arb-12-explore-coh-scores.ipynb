# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

# %%
infile = Path('../reports/viz/full_lim_journal_singlerank_05_05_2020/coherence2020-05-06_20:32:04.csv')
df = pd.read_csv(infile)

# %%
coh1 = 'u_mass'
coh2 = 'c_v'

t = df['n_topics']
data1 = df[coh1]
data2 = df[coh2]

fig, ax1 = plt.subplots()
ax1.set_title('Coherence')

color = 'tab:red'
ax1.set_xlabel('n_topics')
ax1.set_ylabel(coh1, color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel(coh2, color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
