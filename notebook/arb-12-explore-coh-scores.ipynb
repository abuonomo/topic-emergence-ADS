# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

# %%
infile = Path('../scratch/coherence.csv')

# %%
df = pd.read_csv(infile, index_col=0)

xlab = 'num_topics'
ylab = 'coherence (u_mass)'

plt.plot(df[xlab], df[ylab], '-o')
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title("Topic Model Coherence versus Numerber of Topics")
fig = plt.gcf()
