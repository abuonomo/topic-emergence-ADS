# %%
import pandas as pd
import json

# %%
infile = '../reports/viz/full_singlerank_1997_ll_no_hyph_06_05_2020/viz_data450.json'

# %%
with open(infile, 'r') as f0:
    viz_data = json.load(f0)

# %%
viz_data = json.loads(viz_data)

# %%
term_table = pd.DataFrame(viz_data['token.table'])

# %%
term_table['Term'].unique().shape
# Out:
# (4230,)

# %%
q = 'planet form'
term_table[term_table['Term'].apply(lambda x: q in x)]
# Out:
#       Topic      Freq                     Term
# 2359    431  0.976902        giant planet form
# 4125    147  0.000659              planet form
# 4126    431  0.996575              planet form
# 5411    364  0.964213  terrestrial planet form

# %%
pd.read_csv(infile, index_col=0)
# Out:
#                               model  n_topics     u_mass  c_v
# 0   gensim.models.ldamodel.LdaModel       100  -7.563601  NaN
# 1   gensim.models.ldamodel.LdaModel       125  -8.507150  NaN
# 2   gensim.models.ldamodel.LdaModel       150  -9.544034  NaN
# 3   gensim.models.ldamodel.LdaModel       175 -10.290744  NaN
# 4   gensim.models.ldamodel.LdaModel       200 -11.269435  NaN
# 5   gensim.models.ldamodel.LdaModel       225 -11.538569  NaN
# 6   gensim.models.ldamodel.LdaModel       250 -11.807640  NaN
# 7   gensim.models.ldamodel.LdaModel       275 -12.151431  NaN
# 8   gensim.models.ldamodel.LdaModel       300 -11.140552  NaN
# 9   gensim.models.ldamodel.LdaModel       325 -10.368719  NaN
# 10  gensim.models.ldamodel.LdaModel       350  -9.639467  NaN
# 11  gensim.models.ldamodel.LdaModel       375  -8.623499  NaN
# 12  gensim.models.ldamodel.LdaModel       400  -7.804499  NaN
# 13  gensim.models.ldamodel.LdaModel       425  -7.079531  NaN
# ...
