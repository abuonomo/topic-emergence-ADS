# %%
import sys
sys.path.append('../src/')

# %%
import model
# Out:
# /Users/anthony/code/abuonomo/topic-emergence-ADS/venv/lib/python3.8/site-packages/gensim/corpora/dictionary.py:11: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import Mapping, defaultdict
# /Users/anthony/code/abuonomo/topic-emergence-ADS/venv/lib/python3.8/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# /Users/anthony/code/abuonomo/topic-emergence-ADS/venv/lib/python3.8/site-packages/gensim/models/doc2vec.py:73: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import namedtuple, defaultdict, Iterable
# /Users/anthony/code/abuonomo/topic-emergence-ADS/venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
vp = model.VizPrepper()
vp.read_hdf('../models/example_experiment/topic_model20/viz_data.hdf5')
ts_df, chars_df = vp.get_time_characteristics(0.1, year_min=1997, year_max=2010)
kmeans, dtw_man = vp.get_dynamic_time_warp_clusters(ts_df)
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# 100%|██████████| 20/20 [00:00<00:00, 266.74it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.81it/s]
# INFO:dtw_time_analysis:Computing dynamic time warping between keywords.
# INFO:dtw_time_analysis:window: 1.
# INFO:model:Trying kmeans n_clusters from 2 to 20
# INFO:model:Writing elbow to None.
# INFO:model:Performing kmeans with 10 clusters.
# INFO:model:Computing tsne manifold.

# %%
vp.paper_ids
# Out:
# array([   3,    7,    9, ..., 5341, 5343, 5344])

# %%
vp.paper2years['id'].values != vp.paper_ids
# Out:
# 0
