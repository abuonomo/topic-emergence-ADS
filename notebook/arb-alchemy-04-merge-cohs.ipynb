# %%
import sys
sys.path.append('../src/')

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

# %%
from model import get_coherence_plot
# Out:
# /Users/anthony/code/abuonomo/topic-emergence-ADS/venv/lib/python3.8/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# /Users/anthony/code/abuonomo/topic-emergence-ADS/venv/lib/python3.8/site-packages/patsy/constraint.py:13: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import Mapping
# /Users/anthony/code/abuonomo/topic-emergence-ADS/venv/lib/python3.8/site-packages/tsfresh/utilities/distribution.py:14: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import Iterable
# ...

# %%
# reports_dir = Path("../reports/arb-alchemy-no-count-07-10-2020/")
reports_dir = Path("../reports/arb-alchemy-01-07-03-2020/")

# %%
# !ls -lh ../reports/arb-alchemy-no-count-07-10-2020/
# Out:
# total 624
# -rw-r--r--  1 anthony  staff   229B Jul 14 09:24 coherences.csv
# -rw-r--r--  1 anthony  staff    35K Jul 14 09:24 coherences.png
# -rw-r--r--  1 anthony  staff   282B Jul 14 09:24 coherences0.csv
# -rw-r--r--  1 anthony  staff    36K Jul 14 09:24 coherences0.png
# -rw-r--r--  1 anthony  staff   485B Jul 14 09:31 coherences_agg.csv
# -rw-r--r--  1 anthony  staff    23K Jul 14 09:31 coherences_agg.png
# -rw-r--r--@ 1 anthony  staff   201K Jul 14 09:24 keywords.csv

# %%
df0 = pd.read_csv(reports_dir / "coherence.csv", index_col=0)
df1 = pd.read_csv(reports_dir / "coherences.csv", index_col=0)

# %%
dft = df0.append(df1).sort_values('num_topics')

# %%
fig = get_coherence_plot(dft)

# %%
dft.iloc[dft['coherence (u_mass)'].argmax()]
# Out:
# num_topics            750.000000
# coherence (u_mass)     -5.602393
# Name: 1, dtype: float64

# %%
dft.to_csv(reports_dir / "coherences_agg.csv")

# %%
fig.savefig(reports_dir / "coherences_agg.png")
